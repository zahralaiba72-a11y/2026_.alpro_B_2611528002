# %% [markdown]
# <div align="center">
#
# **PRACTICAL REPORT**
#
# **ALGORITHMS AND PROGRAMMING**
#
# **“Module 2: Data Types, Variables, and I/O”**
#
# **Compiled By:**
#
# **Laiba Shamshad**
#
# **2611528002**
#
# **Lecturer:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **PRACTICAL ASSISTENT:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## PREFACE
#
# Praise and gratitude be to Almighty God for all His grace and blessings, enabling the successful and timely completion of this Algorithms and Programming practicum report titled "Store Transaction Simulation and Access Validation System".
#
# This report was prepared to fulfill the Module 3 practicum requirements and to deepen the understanding of fundamental Python programming concepts, specifically the application of arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators within integrated transaction logic.
#
# The author recognizes that this report may still contain areas for improvement. Therefore, constructive feedback and suggestions are welcomed to enhance future work. It is hoped that this report provides valuable insights for readers and fellow students.
#
# Padang, 2026
# Laiba Shamshad

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Background
#
# Along with the rapid development of information technology, the implementation of computerized systems in academic administration and student data management has become an essential requirement across educational institutions. Manual data entry and evaluation processes are often time-consuming and carry a high risk of calculation errors or data type mismatches (human error), which can compromise record accuracy. Therefore, developing an automated registration and verification program capable of processing student records and evaluating performance is crucial for operational efficiency.
#
# In the field of computer programming, Python is widely recognized as a primary language for software development due to its clear, intuitive syntax and strong support for fundamental programming concepts. Essential features such as input/output (I/O) operations, variable assignment, explicit type casting (converting string inputs into integer or float values), multi-line string formatting, complex numbers, and constant declarations form the backbone of reliable software design. Furthermore, relational operators allow programs to dynamically evaluate conditions—such as determining whether a student meets a predefined passing score threshold.
#
# Based on these core concepts, this practicum involves designing and executing the **`tugas2_8002.py`** program. The script processes user inputs (student name, gender, multi-line address, age, and initial score), applies explicit type casting, incorporates constant variables (`PASSING_SCORE_8002`), generates a complex token ID, and validates passing status using boolean logic. This implementation provides practical experience in basic program architecture, data type verification, and console-based decision-making.
#
# ## 1.2 Tujuan/Objectives
# 1.Understand the implementation of primitive and complex data types (string, integer, float, complex, and boolean) in Python.
#
# 2.Apply explicit type casting, constant declarations, and custom variable naming conventions with the student ID suffix (_8002).
#
# 3.Evaluate student qualification status dynamically using relational and logical comparison operators against a predefined constant threshold.
# ## 1.3 Manfaat/ Benefits
# 1.Enhance practical comprehension of Python console input/output (I/O) processing and variable data type verification using the built-in type() function.
#
# 2.Minimize data-handling errors by accurately converting string inputs into appropriate numeric and logical formats for automated academic assessment.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori/Basic theory
#
# Python Programming Language: Python is a high-level, interpreted programming language with a clean and intuitive syntax focused on code readability, making it ideal for learning fundamental programming logic without complex structural overhead.
#
# Input and Output (I/O) Functions: The input() function is used to capture text data from the user through the console, while the print() function displays variables, strings, and execution results to the screen.
#
# Data Types and Type Casting: Python supports primitive and non-primitive data types including strings (str), integers (int), floats (float), complex numbers (complex), and booleans (bool). Because input() defaults to string data, explicit casting (int(), float()) is necessary to convert values for numerical operations.
#
# Constants and Variable Naming: Constants represent fixed values that remain unchanged during execution (e.g., PASSING_SCORE_8002 = 75.0). Variable names follow case-sensitive rules and include the student ID suffix (_8002) for proper tracking.
#
# Relational Operators and Boolean Logic: Relational operators (such as >=) evaluate conditions to return boolean values (True or False), enabling automated decision-making and status verification within the program.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Alpro_B_2611528002"
# Run the code cell below so that Jupyter automatically saves the code along with its output as a single unit (no separate screenshot needed for the execution output).

# %%
PASSING_SCORE_8002 = 75.0

print("=== ALPRO PRACTICUM REGISTRATION SYSTEM 2026 ===")

student_name_8002 = str(input("Enter Student Name : "))
gender_8002 = str(input("Enter Gender (L/P): "))

print("Enter Residential Address (Multi-line format):")
address_8002 = """Jl. Kampus Unand,
Kecamatan Pauh,
Kota Padang"""
print(address_8002)

age_8002 = int(input("Enter Age : "))
initial_score_8002 = float(input("Enter Initial Test Score : "))

token_id_8002 = complex(100, 3)

is_passed_8002 = initial_score_8002 >= PASSING_SCORE_8002

print("\n=== PRACTICUM DATA & CHECK RESULTS ===")
print(f"Student Name   : {student_name_8002} | Type: {type(student_name_8002)}")
print(f"Gender         : {gender_8002} | Type: {type(gender_8002)}")
print(f"Address        :\n{address_8002} | Type: {type(address_8002)}")
print(f"Age            : {age_8002} years old | Type: {type(age_8002)}")
print(f"Initial Score  : {initial_score_8002} | Type: {type(initial_score_8002)}")
print(f"Signal Token ID: {token_id_8002} | Type: {type(token_id_8002)}")
print(f"Passed Status  : {is_passed_8002} | Type: {type(is_passed_8002)}")
# Out:
# === ALPRO PRACTICUM REGISTRATION SYSTEM 2026 ===
# Enter Residential Address (Multi-line format):
# Jl. Kampus Unand,
# Kecamatan Pauh,
# Kota Padang
#
# === PRACTICUM DATA & CHECK RESULTS ===
# Student Name   : 2 | Type: <class 'str'>
# Gender         : P | Type: <class 'str'>
# Address        :
# Jl. Kampus Unand,
# Kecamatan Pauh,
# Kota Padang | Type: <class 'str'>
# Age            : 12 years old | Type: <class 'int'>
# Initial Score  : 9.0 | Type: <class 'float'>
# Signal Token ID: (100+3j) | Type: <class 'complex'>
# Passed Status  : False | Type: <class 'bool'>

# %% [markdown]
# **Penjelasan/ Explanation:**
# 1.The first section initializes constant thresholds (such as PASSING_SCORE_8002) and captures user inputs for student details, including name, gender, multi-line address, age, and initial score, while applying explicit type casting (int, float, str).
#
# 2.The middle section declares complex numeric data (such as token_id_8002) and evaluates boolean validation logic by comparing the student's test score against the constant passing threshold.
#
# 3.The final section outputs all collected data records alongside their corresponding data classes verified through the built-in type() function.

# %% [markdown]
# ### 2.2.2 Program Driver "Driver_2611528002"

# %% [markdown]
# ### Assigment 2

# %%
=== ALPRO PRACTICUM REGISTRATION SYSTEM 2026 ===
Enter Residential Address (Multi-line format):
Jl. Kampus Unand,
Kecamatan Pauh,
Kota Padang

=== PRACTICUM DATA & CHECK RESULTS ===
Student Name   : 2 | Type: <class 'str'>
Gender         : P | Type: <class 'str'>
Address        :
Jl. Kampus Unand,
Kecamatan Pauh,
Kota Padang | Type: <class 'str'>
Age            : 12 years old | Type: <class 'int'>
Initial Score  : 9.0 | Type: <class 'float'>
Signal Token ID: (100+3j) | Type: <class 'complex'>
Passed Status  : False | Type: <class 'bool'>

# %% [markdown]
# ## Asignent 3

# %% [markdown]
# The execution output demonstrates the successful interactive flow of the student registration system.
#
# <div align="center">
# <img src="images/output1.png" width="400"><br>
# <em>Figure 2.1 : Program Execution Output</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# Design a simple console program that records a student's identity data (name, gender, address, age, initial score) and automatically verifies their course completion status. The program must use variables ending with the last 4 digits of your NIM (`_8002`), apply type casting, define a passing threshold constant (`75.0`), and output the dynamic verification status.

# %% [markdown]
# **Kode Jawaban :**
#
# a.  Kode Program "Alpro_B_2611528002"

# %%
# Main assignment script logic
PASSING_SCORE_8002 = 75.0

student_name_8002 = str(input("Enter Student Name: "))
gender_8002 = str(input("Enter Gender (L/P): "))

address_8002 = """Jl. Kampus Unand,
Kecamatan Pauh,
Kota Padang"""

age_8002 = int(input("Enter Age: "))
initial_score_8002 = float(input("Enter Initial Test Score: "))

token_id_8002 = complex(100, 3)

is_passed_8002 = initial_score_8002 >= PASSING_SCORE_8002

print("\n=== PRACTICUM DATA & CHECK RESULTS ===")
print(f"Student Name   : {student_name_8002}")
print(f"Gender         : {gender_8002}")
print(f"Address        :\n{address_8002}")
print(f"Age            : {age_8002}")
print(f"Initial Score  : {initial_score_8002}")
print(f"Signal Token ID: {token_id_8002}")
print(f"Passed Status  : {is_passed_8002}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 11
#       5 gender_8002 = str(input("Enter Gender (L/P): "))
#       7 address_8002 = """Jl. Kampus Unand,
#       8 Kecamatan Pauh,
#       9 Kota Padang"""
# ---> 11 age_8002 = int(input("Enter Age: "))
#      12 initial_score_8002 = float(input("Enter Initial Test Score: "))
#      14 token_id_8002 = complex(100, 3)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# b. Kode Program Driver ""Driver_2611528002"

# %%
import tugas2_8002

# %% [markdown]
# **Output :**
#
# ```text
# === ALPRO PRACTICUM REGISTRATION SYSTEM 2026 ===
# Enter Student Name : Laiba
# Enter Gender (L/P): P
# Enter Residential Address (Multi-line format):
# Jl. Kampus Unand,
# Kecamatan Pauh,
# Kota Padang
# Enter Age : 19
# Enter Initial Test Score : 85.0
#
# === PRACTICUM DATA & CHECK RESULTS ===
# Student Name   : Laiba | Type: <class 'str'>
# Gender         : P | Type: <class 'str'>
# Address        :
# Jl. Kampus Unand,
# Kecamatan Pauh,
# Kota Padang | Type: <class 'str'>
# Age            : 19 years old | Type: <class 'int'>
# Initial Score  : 85.0 | Type: <class 'float'>
# Signal Token ID: (100+3j) | Type: <class 'complex'>
# Passed Status  : True | Type: <class 'bool'>

# %% [markdown]
# ---
# #CHAPTER III
#
# CONCLUSION
#
# Based on the practicum conducted, it can be concluded that:
# 1. Python programming supports managing various data types such as `str`, `int`, `float`, `complex`, and `bool`, which can be converted as needed using type casting functions such as `str()`, `int()`, and `float()`.
# 2. Implementing constants (such as `PASSING_SCORE_8002 = 75.0`) and variables with the NIM suffix (`_8002`) facilitates a logical and structured automation process for validating student completion status.

# %% [markdown]
# ---
# REFERENCES
#
# [1] Python Software Foundation, "Python 3 Documentation: Built-in Types," [Online]. Available: https://docs.python.org/3/library/stdtypes.html. [Accessed: 16 September 2026].
#
# [2] Practicum Lecturer Team, *Algorithms and Programming Practicum Guide 2026: Week 2 - Data Types, Variables, and I/O*, Department of Informatics, Universitas Andalas, 2026.
