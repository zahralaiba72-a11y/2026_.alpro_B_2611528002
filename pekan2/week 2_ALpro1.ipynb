# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan python, vscode, dan koneksi ke github”**
#
# **Disusun Oleh :**
#
# **Laiba Shamshad**
#
# **2611528002**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="Images/logo_unand.png" width="200">
#
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## PREFACE
#
# Praise and gratitude I offer to Almighty God for His grace and blessings, which allowed me to complete this practical report titled “Introduction to Python, VSCode, and Connection to GitHub,” conducted during the first session of the Data Structures Practical Course. This practicum focused on fundamental Python concepts—such as variable declarations, numeric data types, booleans, floating-point operations, strings, and circle area calculations—as well as code management using Visual Studio Code (VSCode) and online repository integration with GitHub.
#
# Through this practicum, I gained direct hands-on experience in implementing basic Python syntax, running scripts within VSCode, and syncing projects seamlessly to GitHub.
#
# I realize that this practical report is still far from perfect. Therefore, constructive criticism and suggestions are highly appreciated for future improvement and development.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I   CHAPTER 1
# ## PENDAHULUAN / INTRODUCTION
#
# ## 1.1 Latar Belakang /summary
# Technological developments in programming make understanding programming languages and supporting tools essential for Informatics students. Python is a programming language used to learn programming basics. Besides the language itself, development tools like Visual Studio Code (VSCode) and GitHub are required to assist in software development and code management.
#
# Therefore, this lab session introduces Python, VSCode, and GitHub connection as a foundational step in program development and project management.
#
# ## 1.2 Tujuan /  objectives
# 1. Learn the basics of using the Python programming language.
# 2. Learn and use Visual Studio Code (VSCode) as a program development environment.
# 3. Understand how to connect projects with GitHub.
#
# ## 1.3 Manfaat /  advantge
# 1. Increase understanding regarding Python usage in programming.
# 2. Improve skills in using VSCode to create and manage programs.
# 3. Know the basics of using GitHub to store and manage programming projects.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori/ Basic Theory
#
# 1. Python: A high-level programming language with simple, easy-to-understand syntax, widely used in learning programming basics.
# 2.Visual Studio Code (VSCode): A code editor used for writing, editing, and running programs. It supports multiple languages and offers extensions to assist development.
# 3. GitHub: An online platform used to store and manage program code, enabling collaboration and version tracking.
# 4. VSCode to GitHub Connection: Allows projects created in VSCode to link directly to a GitHub repository so code can be stored and managed online.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Practical 1/ Numeric "B_2611528002"
# "Run the code cell below so that Jupyter automatically saves the code along with its output as a single unit (no separate screenshot needed for the execution output)."

# %%
#create a file named ik_numeric_NIM.py
# variable name added with the last 4 digits of student ID, exam name_1234 
# craete a variable with numeric type value.
a_1012 = 100
print("the type of variable having value", a_1012, "is", type(a_1012))

#create a variable with float type value.
b_1012 = 100.5
print("the type of variable having value", b_1012, "is", type(b_1012))

#create a variable with complex type value.
c_1012 = 1 + 2j
print("the type of variable having value", c_1012, "is", type(c_1012))

# %% [markdown]
# ### output explanation:
#  The program starts by setting up three different number variables, including a whole number, a decimal number, and a complex number. It then uses a built-in check tool to find out what kind of data format each variable holds. When run, the screen shows each stored value along with its matching type, identifying them as integer, float, and complex classes. Lastly, the program prints these clear details so you can easily see the data type of every number.

# %% [markdown]
# ### 2.2.2 String

# %%
#create a file nsmed string_NIM.py
#variable name added with the last 4 digits of student ID, example: name_1234
#change the program and the respective data
name_8002 = "laiba"
gender_8002 = "F"
address_8002 = """
        unand campus
        pauh District
        Padang city
        """
 religion_8002 = "Islam"
 print("My name is:", name_8002)
 print("My gender is:", gender_8002)        
 print("My address is:", address_8002)
 print("My religion is:", religion_8002)

# %% [markdown]
# ### ouput explanation:
# The program starts by setting up text variables containing personal details like name, gender, a multi-line address, and religion. It then stores these string values to represent specific user information. When run, the screen displays each label followed by its matching details, showing the name, gender, multi-line address, and religion. Lastly, the program prints these text pieces clearly so you can easily read all the personal information.

# %% [markdown]
# ### 2.2.3 Boolean

# %%
#create a file named boolean_2611528002.py
# variable name added with the last 4 digits of student ID, exam name_1234
# Declare  a variable with boolean data type value.
from operator import is_


is_lulus8002 = True
IS_cumlaude_8002 = False

#using boolean
nilai_8002 = 85 #this is a varbiele if numeric 
batas_lulus_8002 =   75

#Determine boolean value from condition
status_kelulusan_8002 = nilai_8002 >= batas_lulus_8002 #the result will be true
print("===check graduation=== ")#this is a string and we executed check graduation
print("grade:", nilai_8002) 
print("Did they pass?:", status_kelulusan_8002)
if is_lulus8002 and IS_cumlaude_8002:
    print("Congratulations, you graduated with the  cum laude honor's!")

# %% [markdown]
# ### output explanation:
# The program starts by setting up simple graduation details, giving a score of 85 and a passing limit of 75, along with preset true-or-false values for passing and cum laude status. It then checks if the score reaches or goes over the passing limit, saving the resulting True value. When run, the screen shows the header ===check graduation===, followed by the student's grade of 85 and the passing status True. Lastly, the program checks if both the passing and cum laude rules are met; since the cum laude variable is set to False, the special congratulation message is not shown in the output.

# %% [markdown]
# ### 2.2.4 Constant

# %%
# create a file named constant_2611528002.py
# this program uses a constant to calculate the area of circle
# variable names are appended with the last 4 digits of student ID, exam name_123
from typing import Final
PI_8002: Final = 3.14 #this is a constant variable
print("pi: %f" % PI_8002) #this is a string and we executed pi
radius_8002 = float(input("Enter the radius value: "))#this is a variable if numeric
area_8002 = PI_8002 * radius_8002 * radius_8002 #this is a variable if numeric
print("The area of the circle with radius %.2f is: %.2f" % (radius_8002, area_8002)) #this is a string and we executed the area of the circle

# %% [markdown]
# ### ouput explanation:
# The program starts by setting up a fixed value for pi and a specific radius number to find the total space inside a circle. It then uses a math formula to multiply pi by the radius squared, saving the final answer. When run, the screen shows the given radius and the resulting circle area formatted with two decimal places. Lastly, the program prints these clear values so you can easily read the final answer.

# %% [markdown]
# ---
# ## Tugas Praktikum /HOMEWORK
#
# Task: Create any Python program file named tugas1_nim.py.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Alpro_B_2611528002"

# %% [markdown]
# ### Title: Student Information Program tugas1_2611528002.py

# %%
# This is student information program
# This program demonstrates variable declaration, variable calls, and printing outputs.

# Variable declarations (storing data values)
student_name = "laiba"  # Stores the student's name as a string
student_nim = "2611528002"  # Stores the student ID number
student_major = "Informatics"  # Stores the academic major
is_active = True  # Stores a boolean value for active enrollment status

# Variable calls and printing the results to the console
print("Student Name:", student_name)
print("Student NIM:", student_nim)
print("Major:", student_major)
print("Active Status:", is_active)

# %% [markdown]
# ### Output explanation:
#
# The program shows the student information by using each saved variable inside the print() functions, causing the screen to print the name, student ID, major, and active status one after another.

# %% [markdown]
# ---
# # BAB III
# ## KESIMPULAN/ CONCLUSION
#
# Based on the practicum conducted, it can be concluded that Python is a programming language that can be used to create and run programs with simple syntax. Visual Studio Code can be used as an environment for writing and running Python code, while GitHub can be used to store and manage projects online.
#
# During the exercises, I learned these things:
#
# * The student information script demonstrated basic variable declaration, variable calls, and printing.
# * The numeric script examined integer, float, and complex data types using the built-in `type()` function.
# * The boolean script utilized conditions and logical operators to evaluate graduation status.
# * The constant script applied mathematical formulas to calculate and format the area of a circle.
# * The string script managed multi-line text variables to display personal biodata clearly.
#
# In this practicum, I learned the basics of using Python, VSCode, and the connection to GitHub. By understanding these three aspects, the process of creating, managing, and storing programs can be carried out in a more structured manner.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Python Documentation," Python, [Online]. Tersedia: https://docs.python.org/3/. [Diakses 6 September 2026].
#
# [2] Microsoft, "Visual Studio Code Documentation," Visual Studio Code, [Online]. Tersedia: https://code.visualstudio.com/docs. [Diakses 6 September 2026].
#
# [3] GitHub, "GitHub Documentation," GitHub, [Online]. Tersedia: https://docs.github.com/. [Diakses 6 September 2026].
